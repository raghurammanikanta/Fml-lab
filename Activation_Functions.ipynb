# %% [markdown]
# <a href="https://colab.research.google.com/github/raghurammanikanta/Fml-lab/blob/main/Activation_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SIGMOID**

# %%
import numpy as np
import matplotlib.pyplot as plt


def sigmoid(x):
  return 1/(1+np.exp(-x))
x=np.linspace(-10,10,100)
plt.plot(x,sigmoid(x))
#plt.axis('tight') is used to remove extra spaces in graphs
plt.title('Activation function :Sigmoid')
plt.show()

# %% [markdown]
# # **TANH**

# %%
import numpy as np
import matplotlib.pyplot as plt1


def tanh(x):
  return np.tanh(x)
x=np.linspace(-10,10,100)
plt1.plot(x,tanh(x))
plt1.axis('tight')
plt1.title('Activation function :tanh')
plt1.show()

# %% [markdown]
# # **ReLU**

# %%
import numpy as np
import matplotlib.pyplot as plt2


def ReLU(x):
  x1=[]
  for i in x:
    if i<0:
      x1.append(0)
    else:
      x1.append(i)
  return x1
x=np.linspace(-10,10,100)
plt2.plot(x,ReLU(x))
plt2.axis('tight')
plt2.title('Activation function :ReLU')
plt2.show()
